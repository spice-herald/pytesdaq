# %%
# Find list of devices connected
import pyvisa

rm = pyvisa.ResourceManager()

resources = rm.list_resources()

for resource in resources:
    print(resource)
    
    
# The output of the `list_resources()` method will be a list of strings, each of which
# corresponds to a different resource. In this case, there is only one resource, which
# is a USB device.
# Out:
# ASRL1::INSTR
# ASRL2::INSTR
# ASRL6::INSTR

# %%
# connect to first device
#resource = 'TCPIP::131.243.51.117::5025::SOCKET'
#resource = 'TCPIP::131.243.51.117::inst0::INSTR'
device = rm.open_resource(resource)

# The `open_resource()` method returns a `pyvisa.Instrument` object, which can be used to send
# commands to the device.

device.write('*IDN?')

# The `write()` method sends a command to the device. In this case, the command is
# the *IDN? command, which requests the device's identification string.

response = device.read()

# The `read()` method reads the response from the device. In this case, the response
# is the device's identification string.

print(response)

# The output of the `read()` method will be the device's identification string.

device.close()

# The `close()` method closes the resource, which releases any resources that the
# device is using.
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# <ipython-input-2-374c3609a7ee> in <module>
#       2 resource = 'TCPIP::131.243.51.117::5025::SOCKET'
#       3 #resource = 'TCPIP::131.243.51.117::inst0::INSTR'
# ----> 4 device = rm.open_resource(resource)
#       5
#       6 # The `open_resource()` method returns a `pyvisa.Instrument` object, which can be used to send
#
# ~/.local/lib/python3.6/site-packages/pyvisa/highlevel.py in open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    3302                 )
#    3303
# -> 3304         res.open(access_mode, open_timeout)
#    3305
#    3306         for key, value in kwargs.items():
#
# ~/.local/lib/python3.6/site-packages/pyvisa/resources/resource.py in open(self, access_mode, open_timeout)
#     296         ):
#     297             self.session, status = self._resource_manager.open_bare_resource(
# --> 298                 self._resource_name, access_mode, open_timeout
#     299             )
#     300
#
# ~/.local/lib/python3.6/site-packages/pyvisa/highlevel.py in open_bare_resource(self, resource_name, access_mode, open_timeout)
#    3230
#    3231         """
# -> 3232         return self.visalib.open(self.session, resource_name, access_mode, open_timeout)
#    3233
#    3234     def open_resource(
#
# ~/.local/lib/python3.6/site-packages/pyvisa/ctwrapper/functions.py in open(library, session, resource_name, access_mode, open_timeout)
#    1850     # ViRsrc converts from (str, unicode, bytes) to bytes
#    1851     ret = library.viOpen(
# -> 1852         session, resource_name, access_mode, open_timeout, byref(out_session)
#    1853     )
#    1854     return out_session.value, ret
#
# ~/.local/lib/python3.6/site-packages/pyvisa/ctwrapper/highlevel.py in _return_handler(self, ret_value, func, arguments)
#     220                 session = None
#     221
# --> 222         return self.handle_return_value(session, ret_value)  # type: ignore
#     223
#     224     def list_resources(
#
# ~/.local/lib/python3.6/site-packages/pyvisa/highlevel.py in handle_return_value(self, session, status_code)
#     249
#     250         if rv < 0:
# --> 251             raise errors.VisaIOError(rv)
#     252
#     253         if rv in self.issue_warning_on:
#
# VisaIOError: VI_ERROR_RSRC_NFOUND (-1073807343): Insufficient location information or the requested device or resource is not present in the system.

# %%
from pytesdaq.instruments.communication import InstrumentComm
myinstrument = InstrumentComm(resource)
# Out:
# /home/mwilliams/.local/lib/python3.6/site-packages/paramiko/transport.py:32: CryptographyDeprecationWarning: Python 3.6 is no longer supported by the Python core team. Therefore, support for it is deprecated in cryptography. The next release of cryptography will remove support for Python 3.6.
#   from cryptography.hazmat.backends import default_backend
# Wakepy using: jeepney (dbus)

# %%
idn = myinstrument.get_idn()
# Out:
# INFO: Opening VISA resource "None"
# ERROR opening VISA resource "None"
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# <ipython-input-5-56cb9828cfd2> in <module>
# ----> 1 idn = myinstrument.get_idn()
#
# ~/.local/lib/python3.6/site-packages/pytesdaq/instruments/communication.py in get_idn(self)
#      52         Query device information
#      53         """
# ---> 54         return self.query('*IDN?')
#      55
#      56
#
# ~/.local/lib/python3.6/site-packages/pytesdaq/instruments/communication.py in query(self, command, coding)
#      98         # connect
#      99         if self._inst is None:
# --> 100             self.connect()
#     101
#     102         # query
#
# ~/.local/lib/python3.6/site-packages/pytesdaq/instruments/communication.py in connect(self)
#     185                     print('INFO: Opening VISA resource "{}"'.format(self._visa_address))
#     186
# --> 187                 self._inst = rm.open_resource(self._visa_address)
#     188                 if self._termination is not None:
#     189                     self._inst.read_termination = self._termination
#
# ~/.local/lib/python3.6/site-packages/pyvisa/highlevel.py in open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    3269
#    3270         if resource_pyclass is None:
# -> 3271             info = self.resource_info(resource_name, extended=True)
#    3272
#    3273             try:
#
# ~/.local/lib/python3.6/site-packages/pyvisa/highlevel.py in resource_info(self, resource_name, extended)
#    3195
#    3196         if extended:
# -> 3197             ret, err = self.visalib.parse_resource_extended(self.session, resource_name)
#    3198         else:
#    3199             ret, err = self.visalib.parse_resource(self.session, resource_name)
#
# ~/.local/lib/python3.6/site-packages/pyvisa/ctwrapper/functions.py in parse_resource_extended(library, session, resource_name)
#    2082         resource_class,
#    2083         unaliased_expanded_resource_name,
# -> 2084         alias_if_exists,
#    2085     )
#    2086
#
# ~/.local/lib/python3.6/site-packages/pyvisa/ctwrapper/highlevel.py in _return_handler(self, ret_value, func, arguments)
#     220                 session = None
#     221
# --> 222         return self.handle_return_value(session, ret_value)  # type: ignore
#     223
#     224     def list_resources(
#
# ~/.local/lib/python3.6/site-packages/pyvisa/highlevel.py in handle_return_value(self, session, status_code)
#     249
#     250         if rv < 0:
# --> 251             raise errors.VisaIOError(rv)
#     252
#     253         if rv in self.issue_warning_on:
#
# VisaIOError: VI_ERROR_INV_RSRC_NAME (-1073807342): Invalid resource reference specified. Parsing error.
